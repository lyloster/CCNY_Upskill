# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv("C:/Users/lylos/github/CCNY_Upskill/IBM_Tools_for_DS/goodreads_library_export.csv")
df.head(5)
# Out:
#     Book Id                   Title           Author        Author l-f  \
# 0  40594396        The Devil Aspect    Craig Russell    Russell, Craig
# 1  29906980    Lincoln in the Bardo  George Saunders  Saunders, George
# 2  26007349         Big Little Lies   Liane Moriarty   Moriarty, Liane
# 3  46041199  Kim Jiyoung, Born 1982      Cho Nam-Joo      Nam-Joo, Cho
# 4   5025780                 Beloved    Toni Morrison    Morrison, Toni
#
#   Additional Authors           ISBN            ISBN13  My Rating  \
# 0                NaN  ="0385544367"  ="9780385544368"          0
# 1                NaN  ="0812995341"  ="9780812995343"          0
# 2      Caroline  Lee            =""  ="9781490627298"          3
# 3        Jamie Chang  ="1631496700"  ="9781631496707"          0
# 4                NaN            =""               =""          0
#
#    Average Rating        Publisher  ... Private Notes  Read Count  \
# 0            4.02  Doubleday Books  ...           NaN           0
# ...

# %%
to_drop = [ "Book Id",
           "Author l-f",
           "Additional Authors",
           "ISBN", 
           "ISBN13",
           "Private Notes",
           "Recommended For", 
           "Recommended By",
           "Owned Copies",
           "Original Purchase Date",
           "Original Purchase Location",
           "Condition",
           "Condition Description",
           "BCID", 
           "My Review", 
           "Spoiler"
          ]
df.drop(to_drop, inplace = True, axis = 1)
df.head(5)
# Out:
#                     Title           Author  My Rating  Average Rating  \
# 0        The Devil Aspect    Craig Russell          0            4.02
# 1    Lincoln in the Bardo  George Saunders          0            3.75
# 2         Big Little Lies   Liane Moriarty          3            4.27
# 3  Kim Jiyoung, Born 1982      Cho Nam-Joo          0            4.15
# 4                 Beloved    Toni Morrison          0            3.86
#
#          Publisher         Binding  Number of Pages  Year Published  \
# 0  Doubleday Books       Hardcover            414.0          2019.0
# 1     Random House       Hardcover            343.0          2017.0
# 2   Recorded Books       Audiobook             16.0          2014.0
# 3        Liveright       Hardcover            176.0          2020.0
# 4          Vintage  Kindle Edition            291.0          2007.0
#
#    Original Publication Year   Date Read  Date Added  \
# 0                     2018.0         NaN  2020/08/17
# ...
