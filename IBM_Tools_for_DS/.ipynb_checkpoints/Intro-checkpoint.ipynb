# %% [markdown]
# Intro
#
# Histogram of an array using Seaborn

# %%
import numpy as np
import seaborn as sns

# %%
x = np.array([1,2,3,4,5,6,5,5,5,5,4,3,2,6,8,9,7,3,2,4,5,2,1])

# %%
sns.distplot(x)
